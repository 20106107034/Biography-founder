# %% [markdown]
# **Importing Library**

# %%
import requests
from bs4 import BeautifulSoup
from tqdm import tqdm

# %% [markdown]
# **Use Input TO Genrate Google Search Link**

# %%
cherater_ =str(input("Enter your cheracher ")).replace(' ','+')
link = 'https://www.google.com/search?q='+cherater_
print(link)
# Out:
# Enter your cheracher Narendra Modi
# https://www.google.com/search?q=Narendra+Modi

# %% [markdown]
# **Scrape Content from Wikipedia add it in link**

# %%
link =link+'=wikipedia'
print(link)
# Out:
# https://www.google.com/search?q=Narendra+Modi=wikipedia

# %% [markdown]
# **Requests send**

# %%
res   = requests.get(link)
soup  = BeautifulSoup(res.text,'html.parser')

# %% [markdown]
# **Update link for  Wikipedia Page**

# %%
lin=''
p=0
for a in soup.find_all('a'):
    lin = a.get('href')
    try:
        if('en.wikipedia.org' in lin):
            lin=lin[7:].split('&')[0]
            break
    except:
        p=1
        pass
print(lin)
# Out:
# https://en.wikipedia.org/wiki/Narendra_Modi

# %% [markdown]
# Agen Send Request Now for Article Scraping

# %%
res     = requests.get(lin)
soup    = BeautifulSoup(res.text,'html.parser')

# %% [markdown]
# **Your Heading**

# %%
heading=soup.find('h1').text
print(heading)
# Out:
# Narendra Modi

# %% [markdown]
# **Article Scraping**

# %%
con=''
temp=0
for p in soup.find_all('p'):
    if(temp>0):
      con_new  = p.text.strip()
      con     += con_new
      con     += '\n'
    else:
      temp=temp+1

con =con.replace('\n\n','')
for i in range(0,470):
    con=con.replace('['+str(i)+']',' ')

# %% [markdown]
# **Write a text file of Article**

# %%
fd=open(heading+'.txt','w')
fd.write(con)
fd.close()
